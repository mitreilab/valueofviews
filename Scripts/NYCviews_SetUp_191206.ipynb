# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import glob
import csv
from datetime import datetime

# %% [markdown]
# # Creating points on a sphere

# %%
# Inputs
theta_max = 40      # angle above horizontal (0-90 deg)
theta_min = 70      # angle below horizontal (0-90 deg, can be positive or negative)
n = 10000             # n = number of points on the sphere (full sphere, before cutting off range of vision)
 
golden_angle = np.pi * (3 - np.sqrt(5))
theta = golden_angle * np.arange(n)      # create an array with n elements
z = np.linspace(1 - 1.0 / n, 1.0 / n - 1, n)     # array with linear spacing from 1-1/n to 1/n-1 with n elements 
radius = np.sqrt(1 - z * z)
 
#selectTheta = np.array[(theta > theta.min) & (theta < theta.max)]

# Create points = array of n elements with [0, 0, 0]
points = np.zeros((n, 3))

points[:,0] = radius * np.cos(theta)
points[:,1] = radius * np.sin(theta)
points[:,2] = z

#select only points within range of vision
angle_max = abs(theta_max)/90
angle_min = -abs(theta_min)/90
selectPts = np.delete(points, np.where(np.logical_or(points[:,2]>angle_max, points[:,2]<=angle_min)), axis=0)

print(selectPts.shape)

# Convert the rays array to dataframe
all_rays_df = pd.DataFrame(selectPts)
# Out:
# (6111, 3)

# %%
# Plot test
pts_x = selectPts[:,0]
pts_y = selectPts[:,1]
pts_z = selectPts[:,2]
 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter3D(pts_x, pts_y, pts_z)

# %% [markdown]
# # Functions for prepping BIN Directories

# %%
# FUNCTION: Concatenate all the pts for all floors into one dataframe
def concatenateAllPts(sourceDir, BIN):
   
    #sourceDir: the directory for all BIN folders
    #BIN: name of BIN (string)

    #Make list of all .pts file in directory
    os.chdir(sourceDir + "\\" + BIN)
    all_lines = []
    for file in glob.glob("*.pts"): 

        # Read .pts file into list and convert to DF
        with open(sourceDir + "\\" + BIN + "\\" + file) as f: 
            lines = f.readlines()
        lines = [x.strip() for x in lines]
        for i in range(len(lines)): 
            oneRow = list(map(float, lines[i].split()))
            del oneRow[-3:]
            all_lines.append(oneRow)

    #Create dataframe with points for all floors in BIN
    BIN_pts_df = pd.DataFrame(all_lines)
    BIN_pts_df.columns = ["x", "y", "z"]

    #print(BIN_pts_df.head())
    print("---> # of points in all floors in BIN (# rows):", BIN_pts_df.shape)
    #print(BIN_pts_df.shape)

    #Check that all floors are represented
    #print("z value of all floors:")
    #print(BIN_pts_df["z"].unique())
    
    return(BIN_pts_df)

# FUNCTION: Create the rays for each point in the BIN grids
def createGridRays(ray_vec_df, BIN_pts_df):

    # ray_vec_df: the trace to trace in a dataframe 
    # BIN_pts_df: all points in the BIN in a dataframe
    
    # Duplicate each row of grid point df by size of vector df and add ray index column
    vectors_df = pd.DataFrame(np.repeat(BIN_pts_df.values, len(ray_vec_df.index), axis=0))
    vectors_df['ray_count'] = vectors_df.groupby(0).cumcount()
    vectors_df = vectors_df.reset_index(drop=True)

    all_vectors = pd.merge(vectors_df, ray_vec_df, left_on='ray_count', right_index=True)
    all_vectors = all_vectors.drop(['ray_count'], axis=1)
    grid_vectors = all_vectors.sort_index()

    print("---> shape of grid df (# points x # rays):", grid_vectors.shape)
    #print(grid_vectors.shape)
    
    return(grid_vectors)

# FUNCTION: Export dataframe to CSV (TAKES A LONG TIME -- V BIG FILES!)
def writeGridRaystoCSV(grid_vectors, sourceDir, BIN):

    #grid_vectors: the output from createGridRays
    #sourceDir: the directory for all BIN folders
    #BIN: name of BIN (string)
    
    print("---> WRITE_START:", datetime.now())
    csvFile = sourceDir + "\\" + BIN + "\\" + BIN + "_rays.csv"
    grid_vectors.to_csv(csvFile, sep=" ", header=False, index=False)
    print("---> WRITE_END:", datetime.now())

    # Check the file size
    size = os.path.getsize(csvFile)
    print("---> csv file size: " + str(size/1e+6) + "mb")

# FUNCTION: Plot test the grid vectors 
def plotGridVectorsTest(grid_vectors):
    
    #Take a small portion of the vectors 
    grid_slice = grid_vectors.truncate(after=600)

    fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
    ax = fig.add_subplot(111, projection='3d')
    ax.quiver(grid_slice["0_x"], grid_slice["1_x"], grid_slice["2_x"], grid_slice["0_y"], grid_slice["1_y"], grid_slice["2_y"])

    #ax.set_zlim(-1.01, 1.01)

    ax.view_init(azim=0, elev=90)
    plt.show()

# %% [markdown]
# # Create csv with ray for full floor analysis grid --- all floors in BIN

# %%
#NYCsourceDir = r"C:\Users\ituran\NYCstudy\BINS"
NYCsourceDir = r"D:\ituran\NYCviews\BINS_to_do"

# Loop through all BINS in directory 
for file in os.listdir(NYCsourceDir): 
    print("---")
    print(file+"_START", datetime.now())
    
    print(file + "_1 concatenate all points in BIN")
    # made dataframe with the points on all floors in the BIN
    allflr_pt_df = concatenateAllPts(NYCsourceDir, file)

    print(file + "_2 make vector for all points in BIN")
    # apply vector rays to all points on all floors in the BIN
    allflr_vector_df = createGridRays(all_rays_df, allflr_pt_df)
    
    print(file + "_3 write vector df to CSV")
    # write the vector array to a file
    writeGridRaystoCSV(allflr_vector_df, NYCsourceDir, file)

    print(file+"_END", datetime.now())
    print("---")
# Out:
# ---
# 1034199_START 2019-12-11 18:10:46.306846
# 1034199_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (8115, 3)
# 1034199_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (23887899, 6)
# 1034199_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:11:10.734732
# ---> WRITE_END: 2019-12-11 18:16:14.108185
# ---> csv file size: 2543.577594mb
# 1034199_END 2019-12-11 18:16:14.108185
# ---
# ---
# 1034200_START 2019-12-11 18:16:14.108185
# 1034200_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1071, 3)
# 1034200_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (2236626, 6)
# 1034200_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:16:16.718489
# ---> WRITE_END: 2019-12-11 18:16:45.621353
# ---> csv file size: 239.587671mb
# 1034200_END 2019-12-11 18:16:45.621353
# ---
# ---
# 1034205_START 2019-12-11 18:16:45.621353
# 1034205_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (642, 3)
# 1034205_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (2108295, 6)
# 1034205_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:16:47.510971
# ---> WRITE_END: 2019-12-11 18:17:14.271670
# ---> csv file size: 225.483945mb
# 1034205_END 2019-12-11 18:17:14.271670
# ---
# ---
# 1034206_START 2019-12-11 18:17:14.271670
# 1034206_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (5809, 3)
# 1034206_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (9093168, 6)
# 1034206_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:17:26.416240
# ---> WRITE_END: 2019-12-11 18:19:20.764615
# ---> csv file size: 958.340553mb
# 1034206_END 2019-12-11 18:19:20.780258
# ---
# ---
# 1034217_START 2019-12-11 18:19:20.780258
# 1034217_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (4170, 3)
# 1034217_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (4161591, 6)
# 1034217_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:19:28.384744
# ---> WRITE_END: 2019-12-11 18:20:20.751073
# ---> csv file size: 443.25426mb
# 1034217_END 2019-12-11 18:20:20.800395
# ---
# ---
# 1034218_START 2019-12-11 18:20:20.800395
# 1034218_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (352, 3)
# 1034218_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1619415, 6)
# 1034218_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:20:21.948741
# ---> WRITE_END: 2019-12-11 18:20:42.329953
# ---> csv file size: 173.221814mb
# 1034218_END 2019-12-11 18:20:42.329953
# ---
# ---
# 1034224_START 2019-12-11 18:20:42.329953
# 1034224_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (3798, 3)
# 1034224_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (3287718, 6)
# 1034224_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:20:49.008892
# ---> WRITE_END: 2019-12-11 18:21:30.393226
# ---> csv file size: 350.532584mb
# 1034224_END 2019-12-11 18:21:30.393226
# ---
# ---
# 1034227_START 2019-12-11 18:21:30.393226
# 1034227_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (2532, 3)
# 1034227_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (12215889, 6)
# 1034227_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:21:39.746048
# ---> WRITE_END: 2019-12-11 18:24:13.851552
# ---> csv file size: 1305.373001mb
# 1034227_END 2019-12-11 18:24:13.851552
# ---
# ---
# 1034228_START 2019-12-11 18:24:13.851552
# 1034228_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (442, 3)
# 1034228_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1637748, 6)
# 1034228_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:24:15.160396
# ---> WRITE_END: 2019-12-11 18:24:35.791599
# ---> csv file size: 174.574898mb
# 1034228_END 2019-12-11 18:24:35.792581
# ---
# ---
# 1034235_START 2019-12-11 18:24:35.792581
# 1034235_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (432, 3)
# 1034235_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1472751, 6)
# 1034235_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:24:36.988500
# ---> WRITE_END: 2019-12-11 18:24:55.536705
# ---> csv file size: 157.202792mb
# 1034235_END 2019-12-11 18:24:55.536705
# ---
# ---
# 1034237_START 2019-12-11 18:24:55.536705
# 1034237_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (114, 3)
# 1034237_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (696654, 6)
# 1034237_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:24:55.946171
# ---> WRITE_END: 2019-12-11 18:25:04.928272
# ---> csv file size: 74.290665mb
# 1034237_END 2019-12-11 18:25:04.928272
# ---
# ---
# 1034240_START 2019-12-11 18:25:04.928272
# 1034240_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1100, 3)
# 1034240_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1466640, 6)
# 1034240_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:25:07.083974
# ---> WRITE_END: 2019-12-11 18:25:25.434210
# ---> csv file size: 156.431955mb
# 1034240_END 2019-12-11 18:25:25.434210
# ---
# ---
# 1034242_START 2019-12-11 18:25:25.434210
# 1034242_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (279, 3)
# 1034242_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1704969, 6)
# 1034242_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:25:26.513079
# ---> WRITE_END: 2019-12-11 18:25:47.892943
# ---> csv file size: 182.04579mb
# 1034242_END 2019-12-11 18:25:47.892943
# ---
# ---
# 1034243_START 2019-12-11 18:25:47.892943
# 1034243_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (434, 3)
# 1034243_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (2652174, 6)
# 1034243_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:25:49.611382
# ---> WRITE_END: 2019-12-11 18:26:25.667017
# ---> csv file size: 283.137526mb
# 1034243_END 2019-12-11 18:26:25.667017
# ---
# ---
# 1034254_START 2019-12-11 18:26:25.667017
# 1034254_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (544, 3)
# 1034254_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1717191, 6)
# 1034254_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:26:27.145777
# ---> WRITE_END: 2019-12-11 18:26:49.373714
# ---> csv file size: 183.4408mb
# 1034254_END 2019-12-11 18:26:49.373714
# ---
# ---
# 1034256_START 2019-12-11 18:26:49.373714
# 1034256_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (190, 3)
# 1034256_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (708876, 6)
# 1034256_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:26:49.884833
# ---> WRITE_END: 2019-12-11 18:26:58.735045
# ---> csv file size: 75.28846mb
# 1034256_END 2019-12-11 18:26:58.735045
# ---
# ---
# 1034326_START 2019-12-11 18:26:58.735045
# 1034326_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (170, 3)
# 1034326_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1038870, 6)
# 1034326_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:26:59.363706
# ---> WRITE_END: 2019-12-11 18:27:12.417935
# ---> csv file size: 110.985988mb
# 1034326_END 2019-12-11 18:27:12.417935
# ---
# ---
# 1034470_START 2019-12-11 18:27:12.417935
# 1034470_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (78, 3)
# 1034470_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (476658, 6)
# 1034470_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:27:12.693374
# ---> WRITE_END: 2019-12-11 18:27:18.653038
# ---> csv file size: 50.946564mb
# 1034470_END 2019-12-11 18:27:18.653038
# ---
# ---
# 1034471_START 2019-12-11 18:27:18.653038
# 1034471_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (339, 3)
# 1034471_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (2071629, 6)
# 1034471_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:27:19.932283
# ---> WRITE_END: 2019-12-11 18:27:45.712483
# ---> csv file size: 221.060586mb
# 1034471_END 2019-12-11 18:27:45.712483
# ---
# ---
# 1034484_START 2019-12-11 18:27:45.712483
# 1034484_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (830, 3)
# 1034484_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (5066019, 6)
# 1034484_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:27:48.965099
# ---> WRITE_END: 2019-12-11 18:28:51.755372
# ---> csv file size: 533.419682mb
# 1034484_END 2019-12-11 18:28:51.755372
# ---
# ---
# 1034485_START 2019-12-11 18:28:51.755372
# 1034485_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1250, 3)
# 1034485_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (3232719, 6)
# 1034485_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:28:54.848920
# ---> WRITE_END: 2019-12-11 18:29:35.147342
# ---> csv file size: 341.578421mb
# 1034485_END 2019-12-11 18:29:35.147342
# ---
# ---
# 1034486_START 2019-12-11 18:29:35.162937
# 1034486_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (166, 3)
# 1034486_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1014426, 6)
# 1034486_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:29:35.788573
# ---> WRITE_END: 2019-12-11 18:29:48.338534
# ---> csv file size: 107.187653mb
# 1034486_END 2019-12-11 18:29:48.338534
# ---
# ---
# 1034487_START 2019-12-11 18:29:48.338534
# 1034487_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (292, 3)
# 1034487_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (916650, 6)
# 1034487_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:29:49.055229
# ---> WRITE_END: 2019-12-11 18:30:00.450107
# ---> csv file size: 96.339234mb
# 1034487_END 2019-12-11 18:30:00.450107
# ---
# ---
# 1034501_START 2019-12-11 18:30:00.450107
# 1034501_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (937, 3)
# 1034501_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (2976057, 6)
# 1034501_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:30:03.028993
# ---> WRITE_END: 2019-12-11 18:30:39.991146
# ---> csv file size: 317.996996mb
# 1034501_END 2019-12-11 18:30:39.991146
# ---
# ---
# 1034502_START 2019-12-11 18:30:39.991146
# 1034502_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1039, 3)
# 1034502_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (4540473, 6)
# 1034502_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:30:43.309284
# ---> WRITE_END: 2019-12-11 18:31:39.801213
# ---> csv file size: 484.189612mb
# 1034502_END 2019-12-11 18:31:39.801213
# ---
# ---
# 1034506_START 2019-12-11 18:31:39.801213
# 1034506_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (3446, 3)
# 1034506_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (8451513, 6)
# 1034506_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:31:48.391908
# ---> WRITE_END: 2019-12-11 18:33:32.816739
# ---> csv file size: 889.844664mb
# 1034506_END 2019-12-11 18:33:32.816739
# ---
# ---
# 1034508_START 2019-12-11 18:33:32.816739
# 1034508_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1351, 3)
# 1034508_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (5078241, 6)
# 1034508_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:33:36.838379
# ---> WRITE_END: 2019-12-11 18:34:39.728813
# ---> csv file size: 536.599104mb
# 1034508_END 2019-12-11 18:34:39.728813
# ---
# ---
# 1034510_START 2019-12-11 18:34:39.728813
# 1034510_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (35868, 3)
# 1034510_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (51540174, 6)
# 1034510_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:35:57.553388
# ---> WRITE_END: 2019-12-11 18:46:42.598284
# ---> csv file size: 5427.683222mb
# 1034510_END 2019-12-11 18:46:42.598284
# ---
# ---
# 1034512_START 2019-12-11 18:46:42.598284
# 1034512_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (5970, 3)
# 1034512_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (21290724, 6)
# 1034512_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:47:02.680854
# ---> WRITE_END: 2019-12-11 18:51:28.031721
# ---> csv file size: 2257.538891mb
# 1034512_END 2019-12-11 18:51:28.031721
# ---
# ---
# 1034520_START 2019-12-11 18:51:28.031721
# 1034520_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (12699, 3)
# 1034520_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (32877180, 6)
# 1034520_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:52:02.361778
# ---> WRITE_END: 2019-12-11 18:58:53.241144
# ---> csv file size: 3473.945855mb
# 1034520_END 2019-12-11 18:58:53.241144
# ---
# ---
# 1034522_START 2019-12-11 18:58:53.241144
# 1034522_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (8435, 3)
# 1034522_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (5426568, 6)
# 1034522_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 18:59:07.928978
# ---> WRITE_END: 2019-12-11 19:00:16.340438
# ---> csv file size: 568.834248mb
# 1034522_END 2019-12-11 19:00:16.340438
# ---
# ---
# 1034532_START 2019-12-11 19:00:16.340438
# 1034532_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (2097, 3)
# 1034532_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (3807153, 6)
# 1034532_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:00:21.215518
# ---> WRITE_END: 2019-12-11 19:01:08.813604
# ---> csv file size: 399.352366mb
# 1034532_END 2019-12-11 19:01:08.813604
# ---
# ---
# 1034807_START 2019-12-11 19:01:08.813604
# 1034807_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1064, 3)
# 1034807_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (2829393, 6)
# 1034807_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:01:11.485171
# ---> WRITE_END: 2019-12-11 19:01:46.132915
# ---> csv file size: 295.628645mb
# 1034807_END 2019-12-11 19:01:46.132915
# ---
# ---
# 1034814_START 2019-12-11 19:01:46.132915
# 1034814_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (270, 3)
# 1034814_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (867762, 6)
# 1034814_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:01:46.828458
# ---> WRITE_END: 2019-12-11 19:01:57.697157
# ---> csv file size: 90.801971mb
# 1034814_END 2019-12-11 19:01:57.697157
# ---
# ---
# 1034815_START 2019-12-11 19:01:57.697157
# 1034815_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (7557, 3)
# 1034815_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (9594270, 6)
# 1034815_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:02:12.200660
# ---> WRITE_END: 2019-12-11 19:04:14.225093
# ---> csv file size: 1006.998896mb
# 1034815_END 2019-12-11 19:04:14.225093
# ---
# ---
# 1034855_START 2019-12-11 19:04:14.225093
# 1034855_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (2852, 3)
# 1034855_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (2933280, 6)
# 1034855_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:04:19.856108
# ---> WRITE_END: 2019-12-11 19:04:58.768805
# ---> csv file size: 307.950666mb
# 1034855_END 2019-12-11 19:04:58.768805
# ---
# ---
# 1035052_START 2019-12-11 19:04:58.768805
# 1035052_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (504, 3)
# 1035052_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1161090, 6)
# 1035052_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:04:59.955792
# ---> WRITE_END: 2019-12-11 19:05:15.330980
# ---> csv file size: 121.807256mb
# 1035052_END 2019-12-11 19:05:15.330980
# ---
# ---
# 1035058_START 2019-12-11 19:05:15.346610
# 1035058_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (112, 3)
# 1035058_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (684432, 6)
# 1035058_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:05:15.849310
# ---> WRITE_END: 2019-12-11 19:05:25.125750
# ---> csv file size: 71.6429mb
# 1035058_END 2019-12-11 19:05:25.125750
# ---
# ---
# 1035062_START 2019-12-11 19:05:25.125750
# 1035062_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1755, 3)
# 1035062_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (4870467, 6)
# 1035062_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:05:30.010376
# ---> WRITE_END: 2019-12-11 19:06:30.528705
# ---> csv file size: 510.482311mb
# 1035062_END 2019-12-11 19:06:30.528705
# ---
# ---
# 1035065_START 2019-12-11 19:06:30.528705
# 1035065_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (81, 3)
# 1035065_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (494991, 6)
# 1035065_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:06:30.823754
# ---> WRITE_END: 2019-12-11 19:06:36.927593
# ---> csv file size: 51.890211mb
# 1035065_END 2019-12-11 19:06:36.927593
# ---
# ---
# 1035066_START 2019-12-11 19:06:36.927593
# 1035066_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (460, 3)
# 1035066_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (2811060, 6)
# 1035066_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:06:38.699676
# ---> WRITE_END: 2019-12-11 19:07:15.124886
# ---> csv file size: 294.287783mb
# 1035066_END 2019-12-11 19:07:15.124886
# ---
# ---
# 1035070_START 2019-12-11 19:07:15.124886
# 1035070_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (104, 3)
# 1035070_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (635544, 6)
# 1035070_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:07:15.516216
# ---> WRITE_END: 2019-12-11 19:07:23.398484
# ---> csv file size: 66.515074mb
# 1035070_END 2019-12-11 19:07:23.399490
# ---
# ---
# 1035071_START 2019-12-11 19:07:23.399490
# 1035071_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (9288, 3)
# 1035071_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (10804248, 6)
# 1035071_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:07:41.178267
# ---> WRITE_END: 2019-12-11 19:09:55.086045
# ---> csv file size: 1130.352932mb
# 1035071_END 2019-12-11 19:09:55.086045
# ---
# ---
# 1035316_START 2019-12-11 19:09:55.086045
# 1035316_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (2304, 3)
# 1035316_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1063314, 6)
# 1035316_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:09:58.828144
# ---> WRITE_END: 2019-12-11 19:10:12.224879
# ---> csv file size: 113.959338mb
# 1035316_END 2019-12-11 19:10:12.224879
# ---
# ---
# 1035318_START 2019-12-11 19:10:12.224879
# 1035318_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (4908, 3)
# 1035318_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (11170908, 6)
# 1035318_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:10:23.994622
# ---> WRITE_END: 2019-12-11 19:12:43.974016
# ---> csv file size: 1189.766246mb
# 1035318_END 2019-12-11 19:12:43.974016
# ---
# ---
# 1035319_START 2019-12-11 19:12:43.974016
# 1035319_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (13197, 3)
# 1035319_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (26301744, 6)
# 1035319_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:13:15.807682
# ---> WRITE_END: 2019-12-11 19:18:48.778375
# ---> csv file size: 2780.96554mb
# 1035319_END 2019-12-11 19:18:48.778375
# ---
# ---
# 1035322_START 2019-12-11 19:18:48.778375
# 1035322_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (2512, 3)
# 1035322_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (2713284, 6)
# 1035322_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:18:53.587378
# ---> WRITE_END: 2019-12-11 19:19:27.418377
# ---> csv file size: 290.222574mb
# 1035322_END 2019-12-11 19:19:27.418377
# ---
# ---
# 1035324_START 2019-12-11 19:19:27.418377
# 1035324_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (738, 3)
# 1035324_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1112202, 6)
# 1035324_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:19:28.919162
# ---> WRITE_END: 2019-12-11 19:19:42.946459
# ---> csv file size: 119.129941mb
# 1035324_END 2019-12-11 19:19:42.946459
# ---
# ---
# 1035328_START 2019-12-11 19:19:42.946459
# 1035328_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (6069, 3)
# 1035328_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (9789822, 6)
# 1035328_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:19:55.714718
# ---> WRITE_END: 2019-12-11 19:21:58.749676
# ---> csv file size: 1045.47654mb
# 1035328_END 2019-12-11 19:21:58.749676
# ---
# ---
# 1035334_START 2019-12-11 19:21:58.749676
# 1035334_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (9504, 3)
# 1035334_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (3990483, 6)
# 1035334_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:22:13.067760
# ---> WRITE_END: 2019-12-11 19:23:02.958726
# ---> csv file size: 422.758582mb
# 1035334_END 2019-12-11 19:23:02.958726
# ---
# ---
# 1035336_START 2019-12-11 19:23:02.958726
# 1035336_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (643, 3)
# 1035336_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (3214386, 6)
# 1035336_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:23:05.332696
# ---> WRITE_END: 2019-12-11 19:23:45.430773
# ---> csv file size: 339.485906mb
# 1035336_END 2019-12-11 19:23:45.430773
# ---
# ---
# 1035344_START 2019-12-11 19:23:45.430773
# 1035344_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (4663, 3)
# 1035344_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (8035965, 6)
# 1035344_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:23:55.290172
# ---> WRITE_END: 2019-12-11 19:25:36.050944
# ---> csv file size: 856.775174mb
# 1035344_END 2019-12-11 19:25:36.050944
# ---
# ---
# 1035347_START 2019-12-11 19:25:36.050944
# 1035347_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (212, 3)
# 1035347_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1295532, 6)
# 1035347_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:25:36.817890
# ---> WRITE_END: 2019-12-11 19:25:53.168358
# ---> csv file size: 138.014017mb
# 1035347_END 2019-12-11 19:25:53.168358
# ---
# ---
# 1035348_START 2019-12-11 19:25:53.168358
# 1035348_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (13950, 3)
# 1035348_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (22378482, 6)
# 1035348_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:26:23.748187
# ---> WRITE_END: 2019-12-11 19:31:02.292638
# ---> csv file size: 2384.793058mb
# 1035348_END 2019-12-11 19:31:02.292638
# ---
# ---
# 1035349_START 2019-12-11 19:31:02.292638
# 1035349_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (5864, 3)
# 1035349_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (9704268, 6)
# 1035349_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:31:15.173115
# ---> WRITE_END: 2019-12-11 19:33:16.894701
# ---> csv file size: 1027.822169mb
# 1035349_END 2019-12-11 19:33:16.894701
# ---
# ---
# 1035350_START 2019-12-11 19:33:16.894701
# 1035350_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1124, 3)
# 1035350_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (3562713, 6)
# 1035350_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:33:20.018720
# ---> WRITE_END: 2019-12-11 19:34:05.199569
# ---> csv file size: 377.129285mb
# 1035350_END 2019-12-11 19:34:05.215190
# ---
# ---
# 1035357_START 2019-12-11 19:34:05.215190
# 1035357_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (7059, 3)
# 1035357_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (11195352, 6)
# 1035357_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:34:19.896447
# ---> WRITE_END: 2019-12-11 19:36:43.785043
# ---> csv file size: 1184.220862mb
# 1035357_END 2019-12-11 19:36:43.785043
# ---
# ---
# 1035360_START 2019-12-11 19:36:43.785043
# 1035360_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (6816, 3)
# 1035360_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (17000802, 6)
# 1035360_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:37:01.593062
# ---> WRITE_END: 2019-12-11 19:40:32.479083
# ---> csv file size: 1797.852614mb
# 1035360_END 2019-12-11 19:40:32.479083
# ---
# ---
# 1035361_START 2019-12-11 19:40:32.479083
# 1035361_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (60, 3)
# 1035361_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (366660, 6)
# 1035361_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:40:32.761519
# ---> WRITE_END: 2019-12-11 19:40:37.326707
# ---> csv file size: 38.898687mb
# 1035361_END 2019-12-11 19:40:37.326707
# ---
# ---
# 1035365_START 2019-12-11 19:40:37.326707
# 1035365_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (750, 3)
# 1035365_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (2322180, 6)
# 1035365_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:40:39.357323
# ---> WRITE_END: 2019-12-11 19:41:08.332750
# ---> csv file size: 247.433887mb
# 1035365_END 2019-12-11 19:41:08.332750
# ---
# ---
# 1035366_START 2019-12-11 19:41:08.332750
# 1035366_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (6357, 3)
# 1035366_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (10077039, 6)
# 1035366_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:41:21.896197
# ---> WRITE_END: 2019-12-11 19:43:27.973714
# ---> csv file size: 1076.737636mb
# 1035366_END 2019-12-11 19:43:27.973714
# ---
# ---
# 1035375_START 2019-12-11 19:43:27.973714
# 1035375_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1936, 3)
# 1035375_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (2279403, 6)
# 1035375_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:43:31.711898
# ---> WRITE_END: 2019-12-11 19:44:00.009319
# ---> csv file size: 241.310819mb
# 1035375_END 2019-12-11 19:44:00.009319
# ---
# ---
# 1035377_START 2019-12-11 19:44:00.009319
# 1035377_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (8268, 3)
# 1035377_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (12759768, 6)
# 1035377_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:44:17.239915
# ---> WRITE_END: 2019-12-11 19:46:55.036387
# ---> csv file size: 1344.027483mb
# 1035377_END 2019-12-11 19:46:55.036387
# ---
# ---
# 1035385_START 2019-12-11 19:46:55.036387
# 1035385_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (29994, 3)
# 1035385_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (41994792, 6)
# 1035385_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:47:59.574281
# ---> WRITE_END: 2019-12-11 19:56:41.014043
# ---> csv file size: 4443.680716mb
# 1035385_END 2019-12-11 19:56:41.014043
# ---
# ---
# 1035394_START 2019-12-11 19:56:41.014043
# 1035394_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1190, 3)
# 1035394_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1106091, 6)
# 1035394_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:56:46.837554
# ---> WRITE_END: 2019-12-11 19:57:00.462991
# ---> csv file size: 116.324141mb
# 1035394_END 2019-12-11 19:57:00.462991
# ---
# ---
# 1035395_START 2019-12-11 19:57:00.462991
# 1035395_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (309, 3)
# 1035395_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1888299, 6)
# 1035395_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:57:01.580614
# ---> WRITE_END: 2019-12-11 19:57:24.926619
# ---> csv file size: 199.73211mb
# 1035395_END 2019-12-11 19:57:24.926619
# ---
# ---
# 1035401_START 2019-12-11 19:57:24.926619
# 1035401_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (3018, 3)
# 1035401_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (6954318, 6)
# 1035401_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:57:32.164850
# ---> WRITE_END: 2019-12-11 19:58:57.861202
# ---> csv file size: 733.885112mb
# 1035401_END 2019-12-11 19:58:57.861202
# ---
# ---
# 1035403_START 2019-12-11 19:58:57.861202
# 1035403_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (9710, 3)
# 1035403_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (17006913, 6)
# 1035403_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 19:59:19.573353
# ---> WRITE_END: 2019-12-11 20:02:49.127547
# ---> csv file size: 1797.596803mb
# 1035403_END 2019-12-11 20:02:49.127547
# ---
# ---
# 1035407_START 2019-12-11 20:02:49.127547
# 1035407_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (2324, 3)
# 1035407_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (5793228, 6)
# 1035407_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:02:54.910132
# ---> WRITE_END: 2019-12-11 20:04:06.412755
# ---> csv file size: 614.094486mb
# 1035407_END 2019-12-11 20:04:06.412755
# ---
# ---
# 1035408_START 2019-12-11 20:04:06.412755
# 1035408_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1421, 3)
# 1035408_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (3599379, 6)
# 1035408_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:04:09.928640
# ---> WRITE_END: 2019-12-11 20:04:55.819349
# ---> csv file size: 380.923211mb
# 1035408_END 2019-12-11 20:04:55.819349
# ---
# ---
# 1035420_START 2019-12-11 20:04:55.819349
# 1035420_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (2150, 3)
# 1035420_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (2945502, 6)
# 1035420_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:04:59.993487
# ---> WRITE_END: 2019-12-11 20:05:36.856687
# ---> csv file size: 311.790076mb
# 1035420_END 2019-12-11 20:05:36.857698
# ---
# ---
# 1035428_START 2019-12-11 20:05:36.857698
# 1035428_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (210, 3)
# 1035428_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (659988, 6)
# 1035428_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:05:37.411079
# ---> WRITE_END: 2019-12-11 20:05:45.688692
# ---> csv file size: 70.350075mb
# 1035428_END 2019-12-11 20:05:45.688692
# ---
# ---
# 1035430_START 2019-12-11 20:05:45.688692
# 1035430_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (669, 3)
# 1035430_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1332198, 6)
# 1035430_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:05:47.158448
# ---> WRITE_END: 2019-12-11 20:06:03.834627
# ---> csv file size: 141.306841mb
# 1035430_END 2019-12-11 20:06:03.834627
# ---
# ---
# 1035434_START 2019-12-11 20:06:03.834627
# 1035434_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (5005, 3)
# 1035434_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (3110499, 6)
# 1035434_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:06:11.672520
# ---> WRITE_END: 2019-12-11 20:06:52.522999
# ---> csv file size: 329.877169mb
# 1035434_END 2019-12-11 20:06:52.522999
# ---
# ---
# 1035438_START 2019-12-11 20:06:52.522999
# 1035438_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (168, 3)
# 1035438_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (525546, 6)
# 1035438_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:06:53.653002
# ---> WRITE_END: 2019-12-11 20:07:00.192350
# ---> csv file size: 55.622176mb
# 1035438_END 2019-12-11 20:07:00.192350
# ---
# ---
# 1035439_START 2019-12-11 20:07:00.192350
# 1035439_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1583, 3)
# 1035439_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (4852134, 6)
# 1035439_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:07:04.605587
# ---> WRITE_END: 2019-12-11 20:08:04.749015
# ---> csv file size: 512.184727mb
# 1035439_END 2019-12-11 20:08:04.749015
# ---
# ---
# 1035443_START 2019-12-11 20:08:04.749015
# 1035443_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (533, 3)
# 1035443_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (2096073, 6)
# 1035443_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:08:06.314374
# ---> WRITE_END: 2019-12-11 20:08:32.366326
# ---> csv file size: 222.133415mb
# 1035443_END 2019-12-11 20:08:32.366326
# ---
# ---
# 1035445_START 2019-12-11 20:08:32.366326
# 1035445_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (528, 3)
# 1035445_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (928872, 6)
# 1035445_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:08:33.465199
# ---> WRITE_END: 2019-12-11 20:08:45.007458
# ---> csv file size: 98.540896mb
# 1035445_END 2019-12-11 20:08:45.008454
# ---
# ---
# 1035448_START 2019-12-11 20:08:45.008454
# 1035448_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (343, 3)
# 1035448_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (2096073, 6)
# 1035448_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:08:46.259656
# ---> WRITE_END: 2019-12-11 20:09:12.296837
# ---> csv file size: 220.733996mb
# 1035448_END 2019-12-11 20:09:12.296837
# ---
# ---
# 1035454_START 2019-12-11 20:09:12.296837
# 1035454_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (5040, 3)
# 1035454_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (10052595, 6)
# 1035454_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:09:23.800824
# ---> WRITE_END: 2019-12-11 20:11:28.019887
# ---> csv file size: 1060.723412mb
# 1035454_END 2019-12-11 20:11:28.019887
# ---
# ---
# 1035455_START 2019-12-11 20:11:28.019887
# 1035455_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (5364, 3)
# 1035455_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (7608195, 6)
# 1035455_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:11:38.679493
# ---> WRITE_END: 2019-12-11 20:13:12.143549
# ---> csv file size: 782.01474mb
# 1035455_END 2019-12-11 20:13:12.143549
# ---
# ---
# 1035464_START 2019-12-11 20:13:12.143549
# 1035464_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (7601, 3)
# 1035464_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (27248949, 6)
# 1035464_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:13:36.965561
# ---> WRITE_END: 2019-12-11 20:19:16.547144
# ---> csv file size: 2886.267755mb
# 1035464_END 2019-12-11 20:19:16.547144
# ---
# ---
# 1035470_START 2019-12-11 20:19:16.547144
# 1035470_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (963, 3)
# 1035470_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (2982168, 6)
# 1035470_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:19:19.368924
# ---> WRITE_END: 2019-12-11 20:19:57.511551
# ---> csv file size: 315.773443mb
# 1035470_END 2019-12-11 20:19:57.511551
# ---
# ---
# 1035471_START 2019-12-11 20:19:57.511551
# 1035471_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (4136, 3)
# 1035471_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (9967041, 6)
# 1035471_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:20:07.669893
# ---> WRITE_END: 2019-12-11 20:22:11.442601
# ---> csv file size: 1053.488296mb
# 1035471_END 2019-12-11 20:22:11.458206
# ---
# ---
# 1035474_START 2019-12-11 20:22:11.458206
# 1035474_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (4988, 3)
# 1035474_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (7626528, 6)
# 1035474_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:22:21.526768
# ---> WRITE_END: 2019-12-11 20:23:56.346933
# ---> csv file size: 807.659049mb
# 1035474_END 2019-12-11 20:23:56.346933
# ---
# ---
# 1035475_START 2019-12-11 20:23:56.346933
# 1035475_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (282, 3)
# 1035475_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1723302, 6)
# 1035475_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:23:57.425140
# ---> WRITE_END: 2019-12-11 20:24:18.719549
# ---> csv file size: 182.445558mb
# 1035475_END 2019-12-11 20:24:18.719549
# ---
# ---
# 1035481_START 2019-12-11 20:24:18.719549
# 1035481_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (773, 3)
# 1035481_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (4717692, 6)
# 1035481_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:24:21.798940
# ---> WRITE_END: 2019-12-11 20:25:19.889973
# ---> csv file size: 493.967447mb
# 1035481_END 2019-12-11 20:25:19.889973
# ---
# ---
# 1035706_START 2019-12-11 20:25:19.889973
# 1035706_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (555, 3)
# 1035706_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1240533, 6)
# 1035706_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:25:21.148420
# ---> WRITE_END: 2019-12-11 20:25:36.839671
# ---> csv file size: 130.709824mb
# 1035706_END 2019-12-11 20:25:36.861193
# ---
# ---
# 1035707_START 2019-12-11 20:25:36.861193
# 1035707_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (227, 3)
# 1035707_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1387197, 6)
# 1035707_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:25:37.722652
# ---> WRITE_END: 2019-12-11 20:25:56.027329
# ---> csv file size: 146.14219mb
# 1035707_END 2019-12-11 20:25:56.027329
# ---
# ---
# 1035709_START 2019-12-11 20:25:56.027329
# 1035709_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (3862, 3)
# 1035709_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (6709878, 6)
# 1035709_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:26:04.653699
# ---> WRITE_END: 2019-12-11 20:27:28.067092
# ---> csv file size: 709.651512mb
# 1035709_END 2019-12-11 20:27:28.067092
# ---
# ---
# 1035711_START 2019-12-11 20:27:28.067092
# 1035711_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1913, 3)
# 1035711_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (4399920, 6)
# 1035711_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:27:32.556438
# ---> WRITE_END: 2019-12-11 20:28:26.651640
# ---> csv file size: 465.727041mb
# 1035711_END 2019-12-11 20:28:26.651640
# ---
# ---
# 1035714_START 2019-12-11 20:28:26.651640
# 1035714_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1338, 3)
# 1035714_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (3293829, 6)
# 1035714_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:28:29.934185
# ---> WRITE_END: 2019-12-11 20:29:10.517299
# ---> csv file size: 348.535138mb
# 1035714_END 2019-12-11 20:29:10.532905
# ---
# ---
# 1035721_START 2019-12-11 20:29:10.532905
# 1035721_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (320, 3)
# 1035721_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1955520, 6)
# 1035721_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:29:11.674374
# ---> WRITE_END: 2019-12-11 20:29:35.886015
# ---> csv file size: 207.227446mb
# 1035721_END 2019-12-11 20:29:35.886015
# ---
# ---
# 1035725_START 2019-12-11 20:29:35.886015
# 1035725_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (120, 3)
# 1035725_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (501102, 6)
# 1035725_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:29:36.226370
# ---> WRITE_END: 2019-12-11 20:29:42.409778
# ---> csv file size: 53.046041mb
# 1035725_END 2019-12-11 20:29:42.409778
# ---
# ---
# 1035727_START 2019-12-11 20:29:42.409778
# 1035727_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (7056, 3)
# 1035727_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (10620918, 6)
# 1035727_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:29:57.010750
# ---> WRITE_END: 2019-12-11 20:32:08.092790
# ---> csv file size: 1122.566432mb
# 1035727_END 2019-12-11 20:32:08.092790
# ---
# ---
# 1035728_START 2019-12-11 20:32:08.092790
# 1035728_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (3930, 3)
# 1035728_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (6428772, 6)
# 1035728_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:32:16.293841
# ---> WRITE_END: 2019-12-11 20:33:35.483097
# ---> csv file size: 677.829055mb
# 1035728_END 2019-12-11 20:33:35.483097
# ---
# ---
# 1035730_START 2019-12-11 20:33:35.483097
# 1035730_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (45, 3)
# 1035730_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (274995, 6)
# 1035730_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:33:35.670609
# ---> WRITE_END: 2019-12-11 20:33:39.057770
# ---> csv file size: 29.102211mb
# 1035730_END 2019-12-11 20:33:39.057770
# ---
# ---
# 1035734_START 2019-12-11 20:33:39.057770
# 1035734_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1523, 3)
# 1035734_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (6569325, 6)
# 1035734_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:33:43.995733
# ---> WRITE_END: 2019-12-11 20:35:07.742900
# ---> csv file size: 691.48838mb
# 1035734_END 2019-12-11 20:35:07.743900
# ---
# ---
# 1035738_START 2019-12-11 20:35:07.743900
# 1035738_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1096, 3)
# 1035738_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1014426, 6)
# 1035738_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:35:09.688797
# ---> WRITE_END: 2019-12-11 20:35:22.645634
# ---> csv file size: 106.533776mb
# 1035738_END 2019-12-11 20:35:22.661236
# ---
# ---
# 1035741_START 2019-12-11 20:35:22.661236
# 1035741_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (816, 3)
# 1035741_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1869966, 6)
# 1035741_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:35:24.516784
# ---> WRITE_END: 2019-12-11 20:35:48.926940
# ---> csv file size: 196.136289mb
# 1035741_END 2019-12-11 20:35:48.973808
# ---
# ---
# 1035747_START 2019-12-11 20:35:48.973808
# 1035747_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (5355, 3)
# 1035747_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (2261070, 6)
# 1035747_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:35:57.862140
# ---> WRITE_END: 2019-12-11 20:36:28.061723
# ---> csv file size: 239.31608mb
# 1035747_END 2019-12-11 20:36:28.061723
# ---
# ---
# 1035751_START 2019-12-11 20:36:28.061723
# 1035751_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (3603, 3)
# 1035751_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (8873172, 6)
# 1035751_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:36:38.132793
# ---> WRITE_END: 2019-12-11 20:38:37.449664
# ---> csv file size: 947.291784mb
# 1035751_END 2019-12-11 20:38:37.449664
# ---
# ---
# 1035753_START 2019-12-11 20:38:37.449664
# 1035753_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1658, 3)
# 1035753_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (3892707, 6)
# 1035753_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:38:41.498432
# ---> WRITE_END: 2019-12-11 20:39:29.984745
# ---> csv file size: 416.212307mb
# 1035753_END 2019-12-11 20:39:29.984745
# ---
# ---
# 1035759_START 2019-12-11 20:39:29.984745
# 1035759_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (5547, 3)
# 1035759_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (5408235, 6)
# 1035759_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:39:40.036026
# ---> WRITE_END: 2019-12-11 20:40:46.919739
# ---> csv file size: 566.619513mb
# 1035759_END 2019-12-11 20:40:46.919739
# ---
# ---
# 1035768_START 2019-12-11 20:40:46.919739
# 1035768_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (525, 3)
# 1035768_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (3208275, 6)
# 1035768_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:40:48.944075
# ---> WRITE_END: 2019-12-11 20:41:28.412959
# ---> csv file size: 331.644642mb
# 1035768_END 2019-12-11 20:41:28.412959
# ---
# ---
# 1035769_START 2019-12-11 20:41:28.412959
# 1035769_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1636, 3)
# 1035769_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (9942597, 6)
# 1035769_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:41:35.350211
# ---> WRITE_END: 2019-12-11 20:43:38.661223
# ---> csv file size: 1040.022359mb
# 1035769_END 2019-12-11 20:43:38.661223
# ---
# ---
# 1035770_START 2019-12-11 20:43:38.661223
# 1035770_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1773, 3)
# 1035770_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1924965, 6)
# 1035770_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:43:42.044959
# ---> WRITE_END: 2019-12-11 20:44:06.009160
# ---> csv file size: 201.766068mb
# 1035770_END 2019-12-11 20:44:06.009160
# ---
# ---
# 1035771_START 2019-12-11 20:44:06.009160
# 1035771_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (3091, 3)
# 1035771_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (6233220, 6)
# 1035771_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:44:12.956442
# ---> WRITE_END: 2019-12-11 20:45:30.724915
# ---> csv file size: 653.272269mb
# 1035771_END 2019-12-11 20:45:30.725919
# ---
# ---
# 1035772_START 2019-12-11 20:45:30.725919
# 1035772_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (2876, 3)
# 1035772_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (3134943, 6)
# 1035772_3 write vector df to CSV
# ---> WRITE_START: 2019-12-11 20:45:36.012304
# ---> WRITE_END: 2019-12-11 20:46:14.807871
# ---> csv file size: 329.966127mb
# 1035772_END 2019-12-11 20:46:14.807871
# ---
# ---
# 1035775_START 2019-12-11 20:46:14.807871
# ...
# ---> WRITE_END: 2019-12-12 01:52:39.919204
# ---> csv file size: 1540.124707mb
# 1082746_END 2019-12-12 01:52:39.919204
# ---
# ---
# 1082895_START 2019-12-12 01:52:39.919204
# 1082895_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1996, 3)
# 1082895_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (6605991, 6)
# 1082895_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 01:52:45.597338
# ---> WRITE_END: 2019-12-12 01:54:08.714037
# ---> csv file size: 700.641653mb
# 1082895_END 2019-12-12 01:54:08.729642
# ---
# ---
# 1082920_START 2019-12-12 01:54:08.729642
# 1082920_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (978, 3)
# 1082920_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (5976558, 6)
# 1082920_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 01:54:12.644607
# ---> WRITE_END: 2019-12-12 01:55:27.481051
# ---> csv file size: 637.775697mb
# 1082920_END 2019-12-12 01:55:27.481051
# ---
# ---
# 1083026_START 2019-12-12 01:55:27.481051
# 1083026_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (21600, 3)
# 1083026_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (9355941, 6)
# 1083026_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 01:56:01.052923
# ---> WRITE_END: 2019-12-12 01:58:02.751069
# ---> csv file size: 1000.93415mb
# 1083026_END 2019-12-12 01:58:02.751069
# ---
# ---
# 1083181_START 2019-12-12 01:58:02.751069
# 1083181_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1812, 3)
# 1083181_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (8072631, 6)
# 1083181_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 01:58:09.220713
# ---> WRITE_END: 2019-12-12 01:59:48.723476
# ---> csv file size: 849.954293mb
# 1083181_END 2019-12-12 01:59:48.723476
# ---
# ---
# 1083346_START 2019-12-12 01:59:48.723476
# 1083346_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (25905, 3)
# 1083346_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (48026349, 6)
# 1083346_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:00:53.986346
# ---> WRITE_END: 2019-12-12 02:10:46.655225
# ---> csv file size: 5090.111137mb
# 1083346_END 2019-12-12 02:10:46.655225
# ---
# ---
# 1083631_START 2019-12-12 02:10:46.655225
# 1083631_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1490, 3)
# 1083631_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (4833801, 6)
# 1083631_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:10:51.408717
# ---> WRITE_END: 2019-12-12 02:11:51.995185
# ---> csv file size: 516.918199mb
# 1083631_END 2019-12-12 02:11:51.996166
# ---
# ---
# 1083640_START 2019-12-12 02:11:51.996166
# 1083640_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (152, 3)
# 1083640_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (928872, 6)
# 1083640_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:11:52.557665
# ---> WRITE_END: 2019-12-12 02:12:04.218696
# ---> csv file size: 98.962555mb
# 1083640_END 2019-12-12 02:12:04.218696
# ---
# ---
# 1083728_START 2019-12-12 02:12:04.218696
# 1083728_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (273, 3)
# 1083728_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1668303, 6)
# 1083728_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:12:05.232382
# ---> WRITE_END: 2019-12-12 02:12:26.183486
# ---> csv file size: 177.824094mb
# 1083728_END 2019-12-12 02:12:26.184468
# ---
# ---
# 1083858_START 2019-12-12 02:12:26.184468
# 1083858_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (153, 3)
# 1083858_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (934983, 6)
# 1083858_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:12:26.759259
# ---> WRITE_END: 2019-12-12 02:12:38.543948
# ---> csv file size: 99.385065mb
# 1083858_END 2019-12-12 02:12:38.543948
# ---
# ---
# 1083859_START 2019-12-12 02:12:38.543948
# 1083859_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1034, 3)
# 1083859_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (6288219, 6)
# 1083859_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:12:42.773803
# ---> WRITE_END: 2019-12-12 02:14:00.588658
# ---> csv file size: 663.430299mb
# 1083859_END 2019-12-12 02:14:00.588658
# ---
# ---
# 1083869_START 2019-12-12 02:14:00.588658
# 1083869_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (5355, 3)
# 1083869_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (5157684, 6)
# 1083869_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:14:09.817948
# ---> WRITE_END: 2019-12-12 02:15:13.350259
# ---> csv file size: 544.358915mb
# 1083869_END 2019-12-12 02:15:13.350259
# ---
# ---
# 1084455_START 2019-12-12 02:15:13.350259
# 1084455_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (6030, 3)
# 1084455_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (4778802, 6)
# 1084455_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:15:23.586693
# ---> WRITE_END: 2019-12-12 02:16:23.771443
# ---> csv file size: 505.189642mb
# 1084455_END 2019-12-12 02:16:23.771443
# ---
# ---
# 1084910_START 2019-12-12 02:16:23.771443
# 1084910_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (280, 3)
# 1084910_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (916650, 6)
# 1084910_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:16:24.518055
# ---> WRITE_END: 2019-12-12 02:16:35.947587
# ---> csv file size: 97.005333mb
# 1084910_END 2019-12-12 02:16:35.980239
# ---
# ---
# 1085502_START 2019-12-12 02:16:35.980239
# 1085502_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (4704, 3)
# 1085502_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (7663194, 6)
# 1085502_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:16:45.754827
# ---> WRITE_END: 2019-12-12 02:18:21.859259
# ---> csv file size: 826.82214mb
# 1085502_END 2019-12-12 02:18:21.859259
# ---
# ---
# 1085969_START 2019-12-12 02:18:21.859259
# 1085969_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (2244, 3)
# 1085969_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (3483270, 6)
# 1085969_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:18:26.381288
# ---> WRITE_END: 2019-12-12 02:19:09.187325
# ---> csv file size: 363.136254mb
# 1085969_END 2019-12-12 02:19:09.187325
# ---
# ---
# 1085972_START 2019-12-12 02:19:09.187325
# 1085972_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (4832, 3)
# 1085972_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (7510419, 6)
# 1085972_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:19:18.861678
# ---> WRITE_END: 2019-12-12 02:20:52.309899
# ---> csv file size: 803.689063mb
# 1085972_END 2019-12-12 02:20:52.309899
# ---
# ---
# 1085979_START 2019-12-12 02:20:52.309899
# 1085979_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (612, 3)
# 1085979_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (3739932, 6)
# 1085979_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:20:54.826996
# ---> WRITE_END: 2019-12-12 02:21:41.869283
# ---> csv file size: 400.326876mb
# 1085979_END 2019-12-12 02:21:41.869283
# ---
# ---
# 1086069_START 2019-12-12 02:21:41.869283
# 1086069_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (10574, 3)
# 1086069_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (4106592, 6)
# 1086069_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:21:57.956121
# ---> WRITE_END: 2019-12-12 02:22:49.830588
# ---> csv file size: 439.176675mb
# 1086069_END 2019-12-12 02:22:49.831594
# ---
# ---
# 1086135_START 2019-12-12 02:22:49.831594
# 1086135_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (5353, 3)
# 1086135_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (10003707, 6)
# 1086135_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:23:01.926714
# ---> WRITE_END: 2019-12-12 02:25:06.180902
# ---> csv file size: 1057.434997mb
# 1086135_END 2019-12-12 02:25:06.180902
# ---
# ---
# 1086510_START 2019-12-12 02:25:06.180902
# 1086510_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (15150, 3)
# 1086510_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (6563214, 6)
# 1086510_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:25:29.233296
# ---> WRITE_END: 2019-12-12 02:26:50.731859
# ---> csv file size: 703.630086mb
# 1086510_END 2019-12-12 02:26:50.763105
# ---
# ---
# 1087119_START 2019-12-12 02:26:50.763105
# 1087119_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (16868, 3)
# 1087119_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (21932379, 6)
# 1087119_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:27:25.280282
# ---> WRITE_END: 2019-12-12 02:31:57.655097
# ---> csv file size: 2331.22913mb
# 1087119_END 2019-12-12 02:31:57.655097
# ---
# ---
# 1087183_START 2019-12-12 02:31:57.655097
# 1087183_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (242, 3)
# 1087183_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (751653, 6)
# 1087183_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:31:58.372207
# ---> WRITE_END: 2019-12-12 02:32:07.674518
# ---> csv file size: 80.042664mb
# 1087183_END 2019-12-12 02:32:07.674518
# ---
# ---
# 1087267_START 2019-12-12 02:32:07.674518
# 1087267_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1442, 3)
# 1087267_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (7467642, 6)
# 1087267_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:32:13.258649
# ---> WRITE_END: 2019-12-12 02:33:46.263378
# ---> csv file size: 789.462809mb
# 1087267_END 2019-12-12 02:33:46.263378
# ---
# ---
# 1087484_START 2019-12-12 02:33:46.263378
# 1087484_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (3039, 3)
# 1087484_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (8812062, 6)
# 1087484_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:33:54.627076
# ---> WRITE_END: 2019-12-12 02:35:44.906453
# ---> csv file size: 942.266143mb
# 1087484_END 2019-12-12 02:35:44.906453
# ---
# ---
# 1087537_START 2019-12-12 02:35:44.906453
# 1087537_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (9725, 3)
# 1087537_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (10193148, 6)
# 1087537_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:36:03.102218
# ---> WRITE_END: 2019-12-12 02:38:11.621023
# ---> csv file size: 1089.605238mb
# 1087537_END 2019-12-12 02:38:11.621023
# ---
# ---
# 1087978_START 2019-12-12 02:38:11.621023
# 1087978_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (24277, 3)
# 1087978_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (17563014, 6)
# 1087978_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:38:54.664651
# ---> WRITE_END: 2019-12-12 02:42:34.032244
# ---> csv file size: 1871.458458mb
# 1087978_END 2019-12-12 02:42:34.110381
# ---
# ---
# 1088582_START 2019-12-12 02:42:34.110381
# 1088582_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (5000, 3)
# 1088582_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (4418253, 6)
# 1088582_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:42:43.175249
# ---> WRITE_END: 2019-12-12 02:43:37.705241
# ---> csv file size: 464.922942mb
# 1088582_END 2019-12-12 02:43:37.705241
# ---
# ---
# 1088660_START 2019-12-12 02:43:37.705241
# 1088660_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (588, 3)
# 1088660_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (892206, 6)
# 1088660_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:43:38.877097
# ---> WRITE_END: 2019-12-12 02:43:49.914797
# ---> csv file size: 94.655305mb
# 1088660_END 2019-12-12 02:43:49.914797
# ---
# ---
# 1088676_START 2019-12-12 02:43:49.914797
# 1088676_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (1119, 3)
# 1088676_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (2419956, 6)
# 1088676_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:43:52.448739
# ---> WRITE_END: 2019-12-12 02:44:22.378269
# ---> csv file size: 255.917349mb
# 1088676_END 2019-12-12 02:44:22.378269
# ---
# ---
# 1088749_START 2019-12-12 02:44:22.378269
# 1088749_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (4290, 3)
# 1088749_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (13700862, 6)
# 1088749_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:44:34.639941
# ---> WRITE_END: 2019-12-12 02:47:25.793408
# ---> csv file size: 1450.007168mb
# 1088749_END 2019-12-12 02:47:25.793408
# ---
# ---
# 1088760_START 2019-12-12 02:47:25.793408
# 1088760_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (16172, 3)
# 1088760_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (30451113, 6)
# 1088760_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:48:03.439771
# ---> WRITE_END: 2019-12-12 02:54:31.738286
# ---> csv file size: 3245.178828mb
# 1088760_END 2019-12-12 02:54:31.738286
# ---
# ---
# 1088856_START 2019-12-12 02:54:31.738286
# 1088856_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (627, 3)
# 1088856_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (1423863, 6)
# 1088856_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:54:33.550903
# ---> WRITE_END: 2019-12-12 02:54:50.965249
# ---> csv file size: 148.506142mb
# 1088856_END 2019-12-12 02:54:50.965249
# ---
# ---
# 1088910_START 2019-12-12 02:54:50.965249
# 1088910_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (30620, 3)
# 1088910_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (94207176, 6)
# 1088910_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 02:56:34.917812
# ---> WRITE_END: 2019-12-12 03:16:10.342846
# ---> csv file size: 9971.170735mb
# 1088910_END 2019-12-12 03:16:10.342846
# ---
# ---
# 1089024_START 2019-12-12 03:16:10.342846
# 1089024_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (9025, 3)
# 1089024_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (17825787, 6)
# 1089024_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 03:16:32.246622
# ---> WRITE_END: 2019-12-12 03:20:17.263044
# ---> csv file size: 1884.358706mb
# 1089024_END 2019-12-12 03:20:17.263044
# ---
# ---
# 1089025_START 2019-12-12 03:20:17.263044
# 1089025_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (128, 3)
# 1089025_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (782208, 6)
# 1089025_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 03:20:17.833543
# ---> WRITE_END: 2019-12-12 03:20:27.859801
# ---> csv file size: 85.033495mb
# 1089025_END 2019-12-12 03:20:28.048490
# ---
# ---
# 1089443_START 2019-12-12 03:20:28.048490
# 1089443_1 concatenate all points in BIN
# ---> # of points in all floors in BIN (# rows): (8836, 3)
# 1089443_2 make vector for all points in BIN
# ---> shape of grid df (# points x # rays): (18577440, 6)
# 1089443_3 write vector df to CSV
# ---> WRITE_START: 2019-12-12 03:20:49.827416
# ---> WRITE_END: 2019-12-12 03:24:44.845450
# ---> csv file size: 1980.442745mb
# 1089443_END 2019-12-12 03:24:44.845450
# ---

# %% [markdown]
# # Create batch file in each BIN folder

# %%
BINSourceDir = r'D:\ituran\NYCviews\testFolder'
source_batch = r"D:\ituran\NYCviews\SimFiles\views_batch_master_D.bat"

# New input text
input_scene_cd = r'D:\ituran\NYCviews\RadScene'
input_oct = r'D:\ituran\NYCviews\RadScene\NYCmodel_all_wSky_r1.oct'

for file in os.listdir(BINSourceDir): 
    
    # Read the source batch file template
    with open(source_batch, "r") as f: 
        sourceFile = f.readlines()

    for i in range(len(sourceFile)): 
        sourceFile[i] = sourceFile[i].replace('cd', 'cd ' + input_scene_cd)
        sourceFile[i] = sourceFile[i].replace('set octreefile=', 'set octreefile=' + input_oct)
        sourceFile[i] = sourceFile[i].replace('set rayFile=', 'set rayFile=' + BINSourceDir + '\\' + file + '\\' + file + '_rays.csv')
        sourceFile[i] = sourceFile[i].replace('set resultsFile=', 'set resultsFile=' + BINSourceDir + '\\' + file + '\\' + file + '_out.dat')

    newBat = BINSourceDir + '\\' + file + '\\' 'view_batch_d.bat'
    with open(newBat, 'w') as out: 
        for i in sourceFile: 
            out.write(i)

# %% [markdown]
# # OLD CODE BELOW!

# %%
# Loop through all .pts files in the directory (glob does not keep order!)
BINdir = r"C:\Users\ituran\NYCstudy\testFolder" 
BIN = str(1000007)

print(str(BINdir + "\\" + BIN))

# %%
#Make list of all .pts file in directory
os.chdir(BINdir + "\\" + BIN)
all_lines = []
for file in glob.glob("*.pts"): 
    
    # Read .pts file into list and convert to DF
    with open(BINdir + "\\" + BIN + "\\" + file) as f: 
        lines = f.readlines()
    lines = [x.strip() for x in lines]
    for i in range(len(lines)): 
        oneRow = list(map(float, lines[i].split()))
        del oneRow[-3:]
        all_lines.append(oneRow)

#Create dataframe with points for all floors in BIN
BIN_pts_df = pd.DataFrame(all_lines)
BIN_pts_df.columns = ["x", "y", "z"]

#print(BIN_pts_df.head())
print(BIN_pts_df.shape)

#Check that all floors are represented
print(BIN_pts_df["z"].unique())

# %%
# Convert the rays array to dataframe
ray_vec_df = pd.DataFrame(selectPts)

# Duplicate each row of grid point df by size of vector df and add ray index column
vectors_df = pd.DataFrame(np.repeat(BIN_pts_df.values, len(ray_vec_df.index), axis=0))
vectors_df['ray_count'] = vectors_df.groupby(0).cumcount()
vectors_df = vectors_df.reset_index(drop=True)

all_vectors = pd.merge(vectors_df, ray_vec_df, left_on='ray_count', right_index=True)
all_vectors = all_vectors.drop(['ray_count'], axis=1)
grid_vectors = all_vectors.sort_index()

# #BLOCK COMMENT SHORTCUT: cmd + / 
# #print(BIN_pts_df)
# print(len(grid_vectors.index))
# print(len(ray_vec_df.index))
# print(len(vectors_df.index))
# print(grid_vectors[0:10])
# print(grid_vectors[300:310])
# print(ray_vec_df[0:10])

print(grid_vectors.shape)
print(grid_vectors['0_x'].idxmax())
print(grid_vectors['0_x'].idxmin())
print(grid_vectors['1_x'].idxmax())
print(grid_vectors['1_x'].idxmin())
print(grid_vectors[609:615])

# %%
# Plot test the grid vectors 

#Take a small portion of the vectors 
grid_slice = grid_vectors.truncate(after=600)

fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111, projection='3d')
ax.quiver(grid_slice["0_x"], grid_slice["1_x"], grid_slice["2_x"], grid_slice["0_y"], grid_slice["1_y"], grid_slice["2_y"])

#ax.set_zlim(-1.01, 1.01)

ax.view_init(azim=0, elev=90)
plt.show()

# %%
# Export dataframe to CSV
grid_vectors.to_csv(BINdir + "\\" + BIN + "\\" + BIN + "_rays.csv", \
                    sep=" ", header=False, index=False)

#### TAKES A WHILE TO SAVE! ####

# %%
# Test that CSV saved properly 
csvFile = BINdir + "\\" + BIN + "\\" + BIN + "_rays.csv"

with open(csvFile, 'r') as f: 
    reader = csv.reader(f, delimiter = " ")
    data = list(reader)
    data = np.array(data).astype(float)

print(data.shape)
print(data[:3])

# %% [markdown]
# # Write batch file for floor

# %% [markdown]
# # -- OLD CODE --

# %%
# Set up batch file and copy other input files to directory 

partsPath = dirPath + ' - parts'
masterBatch = simDir + '\\' + 'views_batch_master.bat'
masterBatRev = dirPath + '\\' + 'views_batch.bat'

# Copy input files into diretory 
otherFiles = ['sky.rad', 'geom.rad', 'geom.oct']
for i in otherFiles: 
    shutil.copyfile(partsPath + '\\' + i, dirPath + '\\' + i)

# Create the batch file
with open(masterBatch, 'r') as f: 
    masterBatFile = f.readlines()
    
for i in range(len(masterBatFile)): 
    masterBatFile[i] = masterBatFile[i].replace('cd', 'cd ' + dirPath)
    masterBatFile[i] = masterBatFile[i].replace('set skyfile=', 'set skyfile=' + dirPath + '\\' + 'sky.rad')
    masterBatFile[i] = masterBatFile[i].replace('set geofile=', 'set geofile=' + dirPath + '\\' + 'geom.rad')
    masterBatFile[i] = masterBatFile[i].replace('set octreefile=', 'set octreefile=' + dirPath + '\\' + 'geom.oct')
    masterBatFile[i] = masterBatFile[i].replace('set rayFile=', 'set rayFile=' + dirPath + '\\' + name + '.txt')
    masterBatFile[i] = masterBatFile[i].replace('set resultsFile=', 'set resultsFile=' + dirPath + '\\' + name + '.dat')

with open(masterBatRev, 'w') as out: 
    for i in masterBatFile: 
        out.write(i)

# %% [markdown]
# # Run batch file

# %% [raw]
# # Run batch file with oconv and rtrace
# if run == True:
#     p = subprocess.Popen(masterBatRev)
#     p.wait()
